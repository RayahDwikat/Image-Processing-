# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('moon.jpg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

row,col = img.shape
x= np.zeros([row,col, 2], dtype=np.uint8)
mask=np.zeros([row,col])
d0 = 40 
for u in range(0, row):
    for v in range(0, col):
        one = (((v - col/2)**2)+ ((u - row/2)**2))**0.5 
        if one <= d0:
            x[u][v] = 1  
            mask[u][v]=1
        else:
            x[u][v] = 0
            mask[u][v]=0
multiimg = dft_shift * imgbuild 
f_ishift = np.fft.ifftshift(multiimg)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
plt.subplot(2,2,1),plt.imshow(img, cmap = 'gray')
plt.title('original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(mask, cmap = 'gray')
plt.title('ideal filter'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(img_back, cmap = 'gray')
plt.title('output image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('moon.jpg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
rows,cols = img.shape
x = np.zeros([rows,cols, 2],dtype=np.uint8)
mask= np.zeros([rows,cols])
d0 = 100
n=5
for u in range(0, rows):
    for v in range(0, cols): 
        r = 1/(1+(((v - cols/2)**2 + (u - rows/2)**2)**0.5)/d0)**2*n
        x[u][v] = 1/(1+(((v - cols/2)**2 + (u - rows/2)**2)**0.5)/d0)**2*n
        mask [u][v]= r        
multiimg = dft_shift * imgbuild 
f_ishift = np.fft.ifftshift(multiimg)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])

plt.subplot(221),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.subplot(223),plt.imshow(mask, cmap = 'gray')
plt.title('butterworth filter'), plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(img_back, cmap = 'gray')
plt.title('otput image'), plt.xticks([]), plt.yticks([])



plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('moon.jpg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))
dft = cv2.dft(np.float32(img),flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
rows,cols = img.shape
x = np.zeros([rows,cols, 2], dtype=np.uint8)
mask = np.zeros([rows,cols])
d0 = 40
e=20
for u in range(0, rows):
for v in range(0, cols): 
r = e**(math.exp(-((((v - cols/2)**2 + (u - rows/2)**2)**0.5)**2)/(2*d0)**2))
x[u][v] =e**(math.exp(-((((v - cols/2)**2 + (u - rows/2)**2)**0.5)**2)/(2*d0)**2))
filtter [u][v]= r        
multiimg = dft_shift * imgbuild 
f_ishift = np.fft.ifftshift(multiimg)
img_back = cv2.idft(f_ishift)
img_back = cv2.magnitude(img_back[:,:,0],img_back[:,:,1])
plt.subplot(2,2,1),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(mask, cmap = 'gray')
plt.title('guassian filtr'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(img_back, cmap = 'gray')
plt.title('otput Image'), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
#   File "<ipython-input-9-5ba5b39c3d6b>", line 16
#     for v in range(0, cols):
#       ^
# IndentationError: expected an indented block
